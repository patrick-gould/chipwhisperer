# %% [markdown]
# # OSU DEMO

# %% [markdown]
# This file expects to be in chipwhisperer/jupyter/courses/fault101. If you opened this in vscode, your local directory might be different. you can either cd' inside this notebook (not in the terminal) to where it expects to be, or adjust the other commands. Specifically, the compiling and programming steps below

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW308_NEORV32'
SS_VER = 'SS_VER_2_1'

# %%
# %run "./jupyter/Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 22
# scope.gain.db                            changed from 15.0                      to 25.091743119266056
# scope.adc.samples                        changed from 131124                    to 5000
# scope.clock.clkgen_freq                  changed from 0                         to 7363636.363636363
# scope.clock.adc_freq                     changed from 0                         to 29454545.454545453
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.cdc_settings                    changed from bytearray(b'\x01\x00\x00\x00') to bytearray(b'\x00\x00\x00\x00')
# scope.glitch.phase_shift_steps           changed from 0                         to 4592
# scope.trace.capture.trigger_source       changed from trace trigger, rule #0    to firmware trigger

# %%
# %%bash -s "$PLATFORM" "$SS_VER"
# cd ./firmware/mcu/simpleserial-glitch-secureboot
# make PLATFORM=$1 CRYPTO_TARGET=NONE SS_VER=$2 -j OPT=0
# Out:
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# riscv64-unknown-elf-gcc (g04696df09) 14.2.0
# Copyright (C) 2024 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CW308_NEORV32
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     secure_boot_signatures_bootloader.c ...
# Compiling:
# Compiling:
# -en     uECC_verify_antifault.c ...
# .
# -en     .././hal//neorv32/neorv32_cfs.c ...
# Compiling:
# -en     .././hal//neorv32/neorv32_cpu.c ...
# -en     simpleserial-glitch-secureboot.c ...
# -en     .././hal/hal.c ...
# -en     .././hal//neorv32/neorv32_gpio.c ...
# uECC_verify_antifault.c:179:13: warning: conflicting types for built-in function 'bcopy'; expected 'void(const void *, void *, unsigned int)' [-Wbuiltin-declaration-mismatch]
#   179 | static void bcopy(uint8_t *dst,
#       |             ^~~~~
# -en     .././simpleserial/simpleserial.c ...
# secure_boot_signatures_bootloader.c:39:22: warning: 'signature_verification_key_start' initialized and declared 'extern'
#    39 | extern const uint8_t signature_verification_key_start = 0;    // The difference between these values need only be 64.
#       |                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# secure_boot_signatures_bootloader.c:40:22: warning: 'signature_verification_key_end' initialized and declared 'extern'
#    40 | extern const uint8_t signature_verification_key_end = SIGNATURE_VERIFICATION_KEYLEN;
#       |                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# secure_boot_signatures_bootloader.c: In function 'esp_secure_boot_verify_ecdsa_signature_block':
# secure_boot_signatures_bootloader.c:96:28: warning: cast to pointer from integer of different size [-Wint-to-pointer-cast]
#    96 |                            (const uint8_t*)signature_verification_key_start, // skip this with fault
#       |                            ^
# secure_boot_signatures_bootloader.c: At top level:
# secure_boot_signatures_bootloader.c:107:8: warning: extra tokens at end of #endif directive [-Wendif-labels]
#   107 | #endif CONFIG_SECURE_SIGNED_APPS_ECDSA_SCHEME // We will always want this to be true
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# .
# .
# .
# Compiling:
# Compiling:
# .
# -en     .././hal//neorv32/neorv32_mtime.c ...
# -en     .././hal//neorv32/neorv32_gptmr.c ...
# Compiling:
# Compiling:
# -e Done!
# -e Done!
# -en     .././hal//neorv32/neorv32_neoled.c ...
# -en     .././hal//neorv32/neorv32_pwm.c ...
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# -e Done!
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_spi.c ...
# -en     .././hal//neorv32/neorv32_rte.c ...
# -en     .././hal//neorv32/neorv32_twi.c ...
# -en     .././hal//neorv32/neorv32_trng.c ...
# -en     .././hal//neorv32/neorv32_slink.c ...
# -e Done!
# -e Done!
# -e Done!
# .
# .
# -e Done!
# .
# .
# Compiling:
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_xip.c ...
# -en     .././hal//neorv32/neorv32_wdt.c ...
# -en     .././hal//neorv32/neorv32_uart.c ...
# Compiling:
# -e Done!
# -e Done!
# .
# .
# .
# -en     .././hal//neorv32/neorv32_xirq.c ...
# -e Done!
# Compiling:
# Assembling: .././hal//neorv32/crt0.S
# riscv64-unknown-elf-gcc -c -march=rv32i_zicsr -mabi=ilp32  -I. -x assembler-with-cpp -Wall -ffunction-sections -fdata-sections -nostartfiles -mno-fdiv -Wl,--gc-sections -lm -lc -lgcc -lc -falign-functions=4 -falign-labels=4 -falign-loops=4 -falign-jumps=4 -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CW308_NEORV32/crt0.lst -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//neorv32 -I.././simpleserial/ -I.././crypto/ .././hal//neorv32/crt0.S -o objdir-CW308_NEORV32/crt0.o
# Compiling:
# -en     .././hal//neorv32/neorv32_hal.c ...
# -e Done!
# -en     .././hal//neorv32/syscalls.c ...
# -e Done!
# -e Done!
# -e Done!
# .././hal//neorv32/syscalls.c:104:6: warning: "/*" within comment [-Wcomment]
#   104 |     //*(volatile int *)EXIT_REG = exit_status;
# .././hal//neorv32/syscalls.c:135:19: warning: 'struct timeb' declared inside parameter list will not be visible outside of this definition or declaration
#   135 | int _ftime(struct timeb *tp)
#       |                   ^~~~~
# .././hal//neorv32/syscalls.c: In function '_sbrk':
# .././hal//neorv32/syscalls.c:267:22: warning: comparison between two arrays [-Warray-compare]
#   267 |     if (__heap_start == __heap_end) {
#       |                      ^~
# .././hal//neorv32/syscalls.c:267:22: note: use '&__heap_start[0] == &__heap_end[0]' to compare the addresses
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     simpleserial-glitch-secureboot-CW308_NEORV32.elf ...
# Memory region         Used Size  Region Size  %age Used
#              ram:        5632 B        64 KB      8.59%
#              rom:       19284 B        64 KB     29.43%
#            iodev:           0 B        512 B      0.00%
# -e Done!
# .
# .
# .
# .
# .
# Creating load file for Flash: simpleserial-glitch-secureboot-CW308_NEORV32.hex
# riscv64-unknown-elf-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-secureboot-CW308_NEORV32.elf simpleserial-glitch-secureboot-CW308_NEORV32.hex
# Creating load file for EEPROM: simpleserial-glitch-secureboot-CW308_NEORV32.eep
# Creating load file for Flash: simpleserial-glitch-secureboot-CW308_NEORV32.bin
# riscv64-unknown-elf-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# 	--change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-glitch-secureboot-CW308_NEORV32.elf simpleserial-glitch-secureboot-CW308_NEORV32.eep || exit 0
# riscv64-unknown-elf-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-secureboot-CW308_NEORV32.elf simpleserial-glitch-secureboot-CW308_NEORV32.bin
# Creating Extended Listing: simpleserial-glitch-secureboot-CW308_NEORV32.lss
# riscv64-unknown-elf-objdump -h -S -z simpleserial-glitch-secureboot-CW308_NEORV32.elf > simpleserial-glitch-secureboot-CW308_NEORV32.lss
# Creating Symbol Table: simpleserial-glitch-secureboot-CW308_NEORV32.sym
# riscv64-unknown-elf-nm -n simpleserial-glitch-secureboot-CW308_NEORV32.elf > simpleserial-glitch-secureboot-CW308_NEORV32.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   19284	      0	   5628	  24912	   6150	simpleserial-glitch-secureboot-CW308_NEORV32.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform iCE40 Target with neorv softcore with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS =
# +--------------------------------------------------------

# %%
# Flash program, init comms.
fw_path = "./firmware/mcu/simpleserial-glitch-secureboot/simpleserial-glitch-secureboot-{}.bin".format(PLATFORM)
cw.program_target(scope, prog, fw_path)
if SS_VER == 'SS_VER_2_1':
    target.reset_comms()

# %%
# Define reboot function. This is different for the ICE40.
#simpleserial-glitch--CW308_NEORV32
#simpleserial-glitch-secureboot--CW308_NEORV32.bin
def reboot_flush():
    #reset_target(scope) # <-- use this for other boards!
    # no reboot on the ICE40 since it doesn't have a way to reset it externally. We just need to reprogram it.
    cw.program_target(scope, prog, fw_path) 
    # Flush garbage too
    target.flush()

# %%
# Set default glitch parameters.
scope.cglitch_setup()

# %%
# Define define graph parameters. Success = good fault; reset = crashed target; normal = benign/uninteresting run.
gc = cw.GlitchController(groups=["success", "reset", "normal"], parameters=["width", "offset", "ext_offset"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='width setting:', disabled=True, max=10.0, readout…
# FloatSlider(value=0.0, continuous_update=False, description='offset setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…

# %%
# Define graph.
gc.glitch_plot(plotdots={"success":"+g", "reset":"xr", "normal":None}, x_index="ext_offset", y_index="offset")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dcbced84-253d-440b-9073-6769fa4e2f70'>
#   <div id="b975ea0e-a07f-44c5-8ff9-a736597279eb" data-root-id="dcbced84-253d-440b-9073-6769fa4e2f70" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a414f012-684f-4c6e-9f95-1c6be0a4f46d":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"dcbced84-253d-440b-9073-6769fa4e2f70"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"47d48734-ba7b-4bce-9bfa-0983314f975c","attributes":{"plot_id":"dcbced84-253d-440b-9073-6769fa4e2f70","comm_id":"e64c55cf805649b79b11f743c8cda3b7","client_comm_id":"7271678bdbbd4cbb95802168a1f33145"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"a414f012-684f-4c6e-9f95-1c6be0a4f46d","roots":{"dcbced84-253d-440b-9073-6769fa4e2f70":"b975ea0e-a07f-44c5-8ff9-a736597279eb"},"root_ids":["dcbced84-253d-440b-9073-6769fa4e2f70"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# :DynamicMap   []
#    :Overlay
#       .Points.I  :Points   [ext_offset,offset]
#       .Points.II :Points   [ext_offset,offset]

# %%
from tqdm.notebook import tqdm
import re
import struct
import time

# Number of runs test we test at each glitch configuration.
sample_size = 1

# Range of cycles we will search around target cycle. 20 cycles is a arbitrary number.
# Replace this value with the range of cycles a benign run would take. 
# You can find this with a few runs with the glitch set past the max runtime.
ERROR_TOLERANCE = 20 

# Target cycle calculated from RTL simulation.
IF_CONDITION = 18110

# Cycles spent bootstrapping and initializing I/O. Chipwhisperer does not count that time. So, subtract that time
MAIN_START = 1463

# Cycle count of simulated program
END_OF_PROGRAM = 18193

# Amount of cycles Chipwhsiperer takes to lower flag on neorv32
TIME_TO_LOWER_TRIGGER = 45

# Difference from if to end of program
DISTANCE_FROM_END_TO_IF = END_OF_PROGRAM - IF_CONDITION

# Chipwhisperer adds two instructions before the funciton call we are simulating. So, Add that time.
CYCLES_FOR_STORE = 6  # Cycles for a storing a word, i.e., 'sw'. Note that this is constant; it is an estimation!
CYCLES_FOR_ADD = 2    # Cycles to add an immediate, i.e., 'addi'
OFFSET = CYCLES_FOR_STORE + CYCLES_FOR_ADD - MAIN_START # Two extra instructions from CW - overhead. Should be negative.



# Note 1: Cycle count is found by running the program and dividing the scope.adc.trig_count, after trigger has been lowered, by 4.
# Note 2: The ADC increments four times each cycle by default. If your numbers are very off, check!

PROGRAM_AVERAGE_CYCLE_COUNT = 12062 # Number of cycles a normal execution takes. (from flag raised to lowered)
SIMULATION_MAX_CYCLE_COUNT = END_OF_PROGRAM - MAIN_START # Number of cycles a simulated execution takes. (from start to end of main)
TIME_SCALAR = PROGRAM_AVERAGE_CYCLE_COUNT/SIMULATION_MAX_CYCLE_COUNT # Quotient of the two program runs.

RANDOM_OFFSET = 20
# Offset start instruction and scale simulated result to match concrete results.
TARGET_CYCLE = PROGRAM_AVERAGE_CYCLE_COUNT - int(TIME_SCALAR*DISTANCE_FROM_END_TO_IF) - TIME_TO_LOWER_TRIGGER - RANDOM_OFFSET# + Time to lower trigger
    
# Set up glitch parameters ranges and step.
gc.set_range("width", 3500, 4500)        # Default values from the solution script
#gc.set_range("offset", 2000, 3200)       # Default values from the solution script
gc.set_range("offset", 2300, 2300)
gc.set_global_step([400, 200, 100])      # Default values from the solution script
#gc.set_range("width", 4300, 4500)       # custom values
#gc.set_range("offset", 2300, 2800)      # custom values
gc.set_range("ext_offset", TARGET_CYCLE - ERROR_TOLERANCE, TARGET_CYCLE + ERROR_TOLERANCE)
#gc.set_range("ext_offset", 40, 200)
#gc.set_range("ext_offset", 1, PROGRAM_MAX_CYCLE_COUNT)
gc.set_step("ext_offset", 1) # We are interested in the whole cycle search space; set step to 1.

scope.glitch.repeat = 1 # This says how many pulses the glitch signal has, not how many times we try. Check docs before touching it!
reboot_flush()
scope.adc.timeout = 1.5 # Number, in seconds, scope will wait before aborting a capture.

hitList = list()        # Holds time and parameters for successful runs
failList = list()       # Holds time and parameters for crashed runs
normalList = list()     # Holds time and parameters for benign runs
counter = 1             # Number of glitches this run.

clock_ID = time.CLOCK_MONOTONIC # Clock considers time since boot, including time the system has been suspended.
start_time = time.clock_gettime(clock_ID) # Get some time, in seconds. This will be our start time.
end_time = start_time # We will update this value each iteration.

for glitch_settings in gc.glitch_values():
    # Grab our settings for this attempt.
    scope.glitch.offset = glitch_settings[1]
    scope.glitch.width = glitch_settings[0]
    scope.glitch.ext_offset = glitch_settings[2]
    
    for i in range(sample_size):
        if scope.adc.state:
            # can detect crash here (fast) before timing out (slow)
            failList.append((end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset))
            gc.add("reset")
            #Device is slow to boot?
            reboot_flush()

        cw.program_target(scope, prog, fw_path)
        scope.arm()
        data = bytearray([0]*5)
        target.simpleserial_write('p', data)
        #target.send_cmd("p", "P", bytearray([0]*5))
        ret = scope.capture()

        # Gather list elements; number of cycles + parameters. ADC counts 4 times each cycle, so we need to divide its count by 4.
        listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
        
        if ret:
            listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
            failList.append(listElement)
            gc.add("reset")
            
            #Device is slow to boot?
            reboot_flush()
        else:
            val = target.simpleserial_read_witherrors('r', 1, glitch_timeout=10, timeout=50) #For loop check
            if val['valid'] is False:
                listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                failList.append(listElement)
                gc.add("reset")
            else:

                if val['payload'] == bytearray([1]): #for loop check
                    listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                    hitList.append(listElement)
                    print(end_time-start_time)
                    gc.add("success")
                else:
                    listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                    normalList.append(listElement)
                    gc.add("normal")        
        end_time = time.clock_gettime(clock_ID) # Update timer
        counter = counter + 1                   # Update interation counter
# Out:
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:552) Unexpected start to command 0x52, expected 0x65
# (ChipWhisperer Target ERROR|File SimpleSerial2.py:574) Missing frame byte at end of packet 0x52
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:587) Invalid CRC. Expected 33 got 60
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:590) Did not receive end of frame, got 82
# (ChipWhisperer Target ERROR|File SimpleSerial2.py:294) Device reported error Unknown error (0x45)
# (ChipWhisperer Target ERROR|File SimpleSerial2.py:295) Full packet: CWbytearray(b'00 52 54 45 3e 20 49 6e 73 74 72 75 63 74 69 6f 6e 20 61 63 63 65 73 73 20 66 61 75 6c 74 20 5b 54 49 4d 45 4f 55 54 5f 45 52 52 5d 20 40 20 50 43 3d 30 78 30 30 30 30 30 32 31 43 00 20 4d 54 56 41 4c 3d 30 78 37 46 34 42 32 30 34 43 20 3c 2f 52 54 45 3e 0d 0a 3c 52')
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:385) Unexpected start to command 0x52, expected 0x72
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:418) Unexpected length 84, 1
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:385) Unexpected start to command 0x52, expected 0x72
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:418) Unexpected length 84, 1
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:533) Read timed out:
# (ChipWhisperer Target ERROR|File SimpleSerial2.py:291) Device did not ack
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:385) Unexpected start to command 0x52, expected 0x72
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:418) Unexpected length 84, 1
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:385) Unexpected start to command 0x52, expected 0x72
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:418) Unexpected length 84, 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 85
#      82     #Device is slow to boot?
#      83     reboot_flush()
# ---> 85 cw.program_target(scope, prog, fw_path)
#      86 scope.arm()
#      87 data = bytearray([0]*5)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/__init__.py:183, in program_target(scope, prog_type, fw_path, **kwargs)
#     181     prog.find()
#     182     prog.erase()
# --> 183     prog.program(fw_path, memtype="flash", verify=True)
#     184     prog.close()
#     185 except:
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/api/programmers.py:129, in save_and_restore_pins.<locals>.func_wrapper(self, *args, **kwargs)
#     126 target_logger.debug('Changing {} pin configuration'.format(pin_setup))
#     128 try:
# --> 129     val = func(self, *args, **kwargs)
#     130 finally:
#     131     target_logger.debug('Restoring {} pin configuration'.format(pin_setup))
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/api/programmers.py:251, in NEORV32Programmer.program(self, filename, memtype, verify)
#     249 @save_and_restore_pins
#     250 def program(self, filename: str, memtype="flash", verify=True):
# --> 251     self.neorv.program(filename)
#     252     pass
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/programmer_neorv32.py:75, in close_on_fail.<locals>.func_wrapper(self, *args, **kwargs)
#      72 @wraps(func)
#      73 def func_wrapper(self, *args, **kwargs):
#      74     try:
# ---> 75         return func(self, *args, **kwargs)
#      76     except:
#      77         self.close_port()
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/programmer_neorv32.py:220, in Neorv32Programmer.program(self, romfilename, bsfile, check_rom_size)
#     213         raise ValueError("This function uploads data to 'code RAM', so limited to 64KB." +
#     214                           " Binary appears to be too large, got %d bytes"%len(romdata))
#     216 # NB - open_port MUST have been called before this or else the start-up messages
#     217 # will be lost.
#     218
#     219 #If no bitstream reloads the built-in
# --> 220 self.load_ice40(bsfile)
#     222 # This time might need to be longer or adjusted on certain builds - TODO test
#     223 time.sleep(0.2)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/programmer_neorv32.py:137, in Neorv32Programmer.load_ice40(self, bsfile, force_ice40type)
#     133     f.close()
#     135 # TODO - currently this uses the 'slower' SPI programming mode as the 'fast' mode only works when passed a file. The fast
#     136 # mode could be made to work fairly easily as getsome() returns a file-like object.
# --> 137 fpga.program(bsdata)
#     139 target_logger.info("iCE40 DONE pin not supported. Maybe it worked!?")
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/programmer_targetfpga.py:308, in LatticeICE40.program(self, bs_path_or_data_or_iobytes, sck_speed, use_fast_usb, start)
#     306 spi = SPI(self.scope._getNAEUSB())
#     307 spi.enable(sck_speed)
# --> 308 spi.transfer(data, writeonly=True)
#     309 if start is True:
#     310     spi.transfer([0]*256, writeonly=True)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/spi.py:134, in SPI.transfer(self, data, start, stop, writeonly)
#     132 wdata = data[si:ei]
#     133 if len(wdata):
# --> 134     rdata = self.transfer_max64(wdata, writeonly=writeonly)
#     135     if writeonly is True:
#     136         readdata = None
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/spi.py:163, in SPI.transfer_max64(self, data, writeonly)
#     160 if len(data) == 0:
#     161     raise ValueError("Length of input data must be > 0")
# --> 163 self.sendCtrl(self.CMD_SPI, self.SPI_CMD_DATA, data)
#     165 #Ignore input data
#     166 if writeonly:
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:874, in NAEUSB.sendCtrl(self, cmd, value, data)
#     870 """
#     871 Send data over control endpoint
#     872 """
#     873 # Vendor-specific, OUT, interface control transfer
# --> 874 self.usbserializer.sendCtrl(cmd, value, data)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:551, in NAEUSB_Backend.sendCtrl(self, cmd, value, data)
#     549 if len(data) > NAEUSB_CTRL_IO_MAX:
#     550     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 551 self.handle.controlWrite(0x41, cmd, value, 0, data, timeout=self._timeout)
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:1406, in USBDeviceHandle.controlWrite(self, request_type, request, value, index, data, timeout)
#    1404 # pylint: enable=undefined-variable
#    1405 data, _ = create_initialised_buffer(data)
# -> 1406 return self._controlTransfer(request_type, request, value, index, data,
#    1407                              sizeof(data), timeout)
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:1379, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
# -> 1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
#    1383     mayRaiseUSBError(result)
#    1384     return result
#
# KeyboardInterrupt:

# %%
# Dump results into .txt files
with open('failList.txt', 'w') as file:
    for item in failList:
        file.write(str(item) + "," + '\n')
with open('hitList.txt', 'w') as file:
    for item in hitList:
        file.write(str(item) + "," + '\n')
with open('normalList.txt', 'w') as file:
    for item in normalList:
        file.write(str(item) + "," + '\n')

# %%
hitList
# Out:
# [(129.863245000015, 7, 316905.0, 3500, 2300, 316717),
#  (259.1081889999914, 13, 316905.0, 3500, 2300, 316723)]

# %%
failList
# Out:
# [(49.34336800000165, 5, 881722.5, 3500, 2300, 463181),
#  (61.6382459999877, 6, 1242800.5, 3500, 2300, 463182),
#  (61.6382459999877, 6, 10245622.5, 3500, 2300, 463182),
#  (87.5328880000161, 7, 10653261.25, 3500, 2300, 463183),
#  (87.5328880000161, 7, 919719.5, 3500, 2300, 463183),
#  (112.04484899999807, 8, 1389135.25, 3500, 2300, 463184),
#  (173.74483099998906, 12, 491650.0, 3500, 2300, 463188),
#  (210.6029780000099, 15, 467697.0, 3500, 2300, 463191),
#  (259.96496700000716, 19, 845201.5, 3500, 2300, 463195),
#  (272.2675870000385, 20, 1163608.75, 3500, 2300, 463196),
#  (321.0086040000315, 23, 917406.5, 3500, 2300, 463199),
#  (333.3350940000382, 24, 1320105.75, 3500, 2300, 463200),
#  (369.96580400003586, 26, 777036.25, 3500, 2300, 463202),
#  (369.96580400003586, 26, 846132.5, 3500, 2300, 463202),
#  (394.41287400003057, 27, 1302615.75, 3500, 2300, 463203),
#  (431.1310999999987, 29, 996098.5, 3500, 2300, 463205),
#  (443.5316890000249, 30, 1386359.75, 3500, 2300, 463206),
#  (480.6333319999976, 32, 463309.0, 3500, 2300, 463208)]

# %%
normalList #494370.0
# Out:
# [(0.0, 1, 12062.0, 3500, 2300, 8888888),
#  (12.646672999981092, 2, 12062.0, 3500, 2300, 8888889),
#  (25.16706099998555, 3, 12062.0, 3500, 2300, 8888890),
#  (37.651161999994656, 4, 12062.0, 3500, 2300, 8888891),
#  (50.33129099998041, 5, 12062.0, 3500, 2300, 8888892),
#  (62.96671699997387, 6, 12062.0, 3500, 2300, 8888893),
#  (75.56257099998766, 7, 12062.0, 3500, 2300, 8888894),
#  (88.21653799997875, 8, 12062.0, 3500, 2300, 8888895),
#  (100.78540999998222, 9, 12062.0, 3500, 2300, 8888896),
#  (113.3410299999814, 10, 12062.0, 3500, 2300, 8888897),
#  (126.00956299999962, 11, 12062.0, 3500, 2300, 8888898),
#  (138.52871899999445, 12, 12062.0, 3500, 2300, 8888899),
#  (151.11148599997978, 13, 12062.0, 3500, 2300, 8888900),
#  (163.53173399998923, 14, 12062.0, 3500, 2300, 8888901)]

# %%
results = gc.calc(ignore_params=["width", "offset"], sort="success_rate")
results

# %% [markdown]
# And one for your width/offset settings:

# %%
results = gc.calc(sort="total")
results

# %%
scope.dis()
target.dis()

# %%
assert broken is True
