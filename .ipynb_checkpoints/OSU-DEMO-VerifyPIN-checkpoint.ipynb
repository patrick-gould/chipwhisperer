# %% [markdown]
# # OSU DEMO

# %% [markdown]
# This file expects to be in chipwhisperer/jupyter/courses/fault101. If you opened this in vscode, your local directory might be different. you can either cd' inside this notebook (not in the terminal) to where it expects to be, or adjust the other commands. Specifically, the compiling and programming steps below

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW308_NEORV32'
SS_VER = 'SS_VER_2_1'

# %%
# %run "./jupyter/Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.clip_errors_disabled           changed from True                      to False
# scope.adc.lo_gain_errors_disabled        changed from True                      to False
# scope.io.hs2                             changed from glitch                    to clkgen
# scope.glitch.enabled                     changed from True                      to False
# scope.glitch.mmcm_locked                 changed from True                      to False
# scope.glitch.width                       changed from 3500                      to 0
# scope.glitch.offset                      changed from 2300                      to 0

# %%
# %%bash -s "$PLATFORM" "$SS_VER"
# cd ./firmware/mcu/simpleserial-glitch-VerifyPIN
# make PLATFORM=$1 CRYPTO_TARGET=NONE SS_VER=$2 -j OPT=0
# Out:
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# riscv64-unknown-elf-gcc (g04696df09) 14.2.0
# Copyright (C) 2024 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CW308_NEORV32
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     initialize.c ...
# -en     simpleserial-glitch-VerifyPIN.c ...
# -en     countermeasure.c ...
# -en     .././hal/hal.c ...
# -en     .././hal//neorv32/neorv32_cfs.c ...
# -en     code.c ...
# Compiling:
# Compiling:
# .
# .
# -en     verifyPIN.c ...
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_cpu.c ...
# -en     .././hal//neorv32/neorv32_gpio.c ...
# -en     .././simpleserial/simpleserial.c ...
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_neoled.c ...
# -en     .././hal//neorv32/neorv32_gptmr.c ...
# -en     .././hal//neorv32/neorv32_mtime.c ...
# -en     .././hal//neorv32/neorv32_pwm.c ...
# -e Done!
# -e Done!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_spi.c ...
# -en     .././hal//neorv32/neorv32_rte.c ...
# -en     .././hal//neorv32/neorv32_slink.c ...
# Compiling:
# -e Done!
# -e Done!
# -e Done!
# -en     .././hal//neorv32/neorv32_trng.c ...
# -e Done!
# -e Done!
# -e Done!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     .././hal//neorv32/neorv32_twi.c ...
# -en     .././hal//neorv32/neorv32_uart.c ...
# .
# -en     .././hal//neorv32/neorv32_wdt.c ...
# Compiling:
# -en     .././hal//neorv32/neorv32_xip.c ...
# -e Done!
# .
# -en     .././hal//neorv32/neorv32_xirq.c ...
# Compiling:
# -e Done!
# -en     .././hal//neorv32/neorv32_hal.c ...
# -e Done!
# .
# -e Done!
# Compiling:
# -e Done!
# -e Done!
# .
# -en     .././hal//neorv32/syscalls.c ...
# Assembling: .././hal//neorv32/crt0.S
# riscv64-unknown-elf-gcc -c -march=rv32i_zicsr -mabi=ilp32  -I. -x assembler-with-cpp -Wall -ffunction-sections -fdata-sections -nostartfiles -mno-fdiv -Wl,--gc-sections -lm -lc -lgcc -lc -falign-functions=4 -falign-labels=4 -falign-loops=4 -falign-jumps=4 -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CW308_NEORV32/crt0.lst -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//neorv32 -I.././simpleserial/ -I.././crypto/ .././hal//neorv32/crt0.S -o objdir-CW308_NEORV32/crt0.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .././hal//neorv32/syscalls.c:104:6: warning: "/*" within comment [-Wcomment]
#   104 |     //*(volatile int *)EXIT_REG = exit_status;
# .././hal//neorv32/syscalls.c:135:19: warning: 'struct timeb' declared inside parameter list will not be visible outside of this definition or declaration
#   135 | int _ftime(struct timeb *tp)
#       |                   ^~~~~
# .././hal//neorv32/syscalls.c: In function '_sbrk':
# .././hal//neorv32/syscalls.c:267:22: warning: comparison between two arrays [-Warray-compare]
#   267 |     if (__heap_start == __heap_end) {
#       |                      ^~
# .././hal//neorv32/syscalls.c:267:22: note: use '&__heap_start[0] == &__heap_end[0]' to compare the addresses
# -e Done!
# .
# LINKING:
# -en     simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf ...
# Memory region         Used Size  Region Size  %age Used
#              ram:        5648 B        64 KB      8.62%
#              rom:       10312 B        64 KB     15.73%
#            iodev:           0 B        512 B      0.00%
# -e Done!
# .
# .
# .
# .
# .
# Creating load file for Flash: simpleserial-glitch-VerifyPIN-CW308_NEORV32.bin
# riscv64-unknown-elf-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf simpleserial-glitch-VerifyPIN-CW308_NEORV32.bin
# Creating Extended Listing: simpleserial-glitch-VerifyPIN-CW308_NEORV32.lss
# riscv64-unknown-elf-objdump -h -S -z simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf > simpleserial-glitch-VerifyPIN-CW308_NEORV32.lss
# Creating Symbol Table: simpleserial-glitch-VerifyPIN-CW308_NEORV32.sym
# Creating load file for EEPROM: simpleserial-glitch-VerifyPIN-CW308_NEORV32.eep
# riscv64-unknown-elf-nm -n simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf > simpleserial-glitch-VerifyPIN-CW308_NEORV32.sym
# Creating load file for Flash: simpleserial-glitch-VerifyPIN-CW308_NEORV32.hex
# riscv64-unknown-elf-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# 	--change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf simpleserial-glitch-VerifyPIN-CW308_NEORV32.eep || exit 0
# riscv64-unknown-elf-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf simpleserial-glitch-VerifyPIN-CW308_NEORV32.hex
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   10312	      0	   5636	  15948	   3e4c	simpleserial-glitch-VerifyPIN-CW308_NEORV32.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform iCE40 Target with neorv softcore with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS =
# +--------------------------------------------------------

# %%
# Flash program, init comms.
fw_path = "./firmware/mcu/simpleserial-glitch-VerifyPIN/simpleserial-glitch-VerifyPIN-{}.bin".format(PLATFORM)
cw.program_target(scope, prog, fw_path)
if SS_VER == 'SS_VER_2_1':
    target.reset_comms()

# %%
# Define reboot function. This is different for the ICE40.
def reboot_flush():
    #reset_target(scope) # <-- use this for other boards!
    # no reboot on the ICE40 since it doesn't have a way to reset it externally. We just need to reprogram it.
    cw.program_target(scope, prog, fw_path) 
    #Flush garbage too
    target.flush()

# %%
# Set default glitch parameters.
scope.cglitch_setup()

# %%
# Define define graph parameters
gc = cw.GlitchController(groups=["success", "reset", "normal"], parameters=["width", "offset", "ext_offset"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='width setting:', disabled=True, max=10.0, readout…
# FloatSlider(value=0.0, continuous_update=False, description='offset setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…

# %%
# Define graph.
gc.glitch_plot(plotdots={"success":"+g", "reset":"xr", "normal":None}, x_index="ext_offset", y_index="offset")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b6999ba4-e01c-432c-a613-76b559c5f7cf'>
#   <div id="c627e188-8d86-4fe0-9683-e52e0a336efc" data-root-id="b6999ba4-e01c-432c-a613-76b559c5f7cf" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7a74df6e-0ac9-4a6c-bbf6-77acfdd0021d":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b6999ba4-e01c-432c-a613-76b559c5f7cf"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b80d1dba-cd5c-44a9-a05e-878a8a04cd23","attributes":{"plot_id":"b6999ba4-e01c-432c-a613-76b559c5f7cf","comm_id":"7a597b08e718447daa054311c3d202b1","client_comm_id":"695df68823434eb2af696cf61a567ffe"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"7a74df6e-0ac9-4a6c-bbf6-77acfdd0021d","roots":{"b6999ba4-e01c-432c-a613-76b559c5f7cf":"c627e188-8d86-4fe0-9683-e52e0a336efc"},"root_ids":["b6999ba4-e01c-432c-a613-76b559c5f7cf"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Parameter name clashes for keys ['data']</br>
# :DynamicMap   []
#    :Overlay
#       .Points.I  :Points   [ext_offset,offset]
#       .Points.II :Points   [ext_offset,offset]

# %%
from tqdm.notebook import tqdm
import re
import struct
import time

# Number of runs test we test at each glitch configuration.
sample_size = 1

# Range of cycles we will search around target cycle.
ERROR_TOLERANCE = 20

# Target cycle calculated from RTL simulation.
ATTACK_CANDIDATE = 6243

# Cycles spent bootstrapping and initializing I/O. Chipwhisperer does not count that time. So, subtract that time
MAIN_START = 5275

# Chipwhisperer adds two instructions before the funciton call we are simulating. So, Add that time.
# Also, add time to account for the trigger calls. Exact time is unknown for lowering, assume similar to raising = 45.
CYCLES_FOR_STORE = 6  # Cycles for a storing a word, i.e., 'sw'
CYCLES_FOR_ADD = 2    # Cycles to add an immediate, i.e., 'addi'

# Accruracy for estimations seems to aim a little high for our samples on CW, so, adjust it down.
AVERAGE_ERROR = -50.167
OFFSET = 0# int(CYCLES_FOR_STORE + CYCLES_FOR_ADD + AVERAGE_ERROR)


# Note 1: Cycle count found running program and dividing the scope.adc.trig_count, after trigger has been lowered, by 4.
# Note 2: The ADC increments four times each cycle by default. If your numbers are very off, check!
PROGRAM_AVERAGE_CYCLE_COUNT = 1044             # Number of cycles a normal execution takes.
SIMULATION_MAX_CYCLE_COUNT = 6419 - MAIN_START # Number of cycles a simulated execution takes.
SIMULATION_IF_CYCLE_COUNT = ATTACK_CANDIDATE - MAIN_START + OFFSET
TIME_SCALAR = PROGRAM_AVERAGE_CYCLE_COUNT/SIMULATION_MAX_CYCLE_COUNT # Quotient of the two program runs.
INVERSE_SCALE = SIMULATION_MAX_CYCLE_COUNT/PROGRAM_AVERAGE_CYCLE_COUNT

TARGET_CYCLE = int((SIMULATION_IF_CYCLE_COUNT) * TIME_SCALAR)
    
# Set up glitch parameters ranges and step.
gc.set_range("width", 3500, 4500)        # Default values from the solution script
#gc.set_range("offset", 2000, 3200)       # Default values from the solution script
gc.set_range("offset", 2300, 2300)
gc.set_global_step([400, 200, 100])      # Default values from the solution script
#gc.set_range("width", 4300, 4500)       # custom values
#gc.set_range("offset", 2300, 2800)      # custom values
gc.set_range("ext_offset", TARGET_CYCLE - ERROR_TOLERANCE, TARGET_CYCLE + ERROR_TOLERANCE)
#gc.set_range("ext_offset", 40, 200)
#gc.set_range("ext_offset", 1, PROGRAM_MAX_CYCLE_COUNT)
gc.set_step("ext_offset", 1) # We are interested in the whole cycle search space; set step to 1.

scope.glitch.repeat = 1 # This says how many pulses the glitch signal has, not how many times we try. Check docs before touching it!
reboot_flush()
scope.adc.timeout = 1.5 # Number, in seconds, scope will wait before aborting a capture.

hitList = list()        # Holds time and parameters for successful runs
failList = list()       # Holds time and parameters for crashed runs
normalList = list()     # Holds time and parameters for benign runs
counter = 1             # Attempt counter.

clock_ID = time.CLOCK_MONOTONIC # Clock considers time since boot, including time the system has been suspended.
start_time = time.clock_gettime(clock_ID) # Get some time, in seconds. This will be our start time.
end_time = start_time # We will update this value each iteration.

for glitch_settings in gc.glitch_values():
    #start_time = time.time_ns()
    scope.glitch.offset = glitch_settings[1]
    scope.glitch.width = glitch_settings[0]
    scope.glitch.ext_offset = glitch_settings[2]
    for i in range(sample_size):
        if scope.adc.state:
            # can detect crash here (fast) before timing out (slow)
            failList.append((end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset))
            gc.add("reset")
            #Device is slow to boot?
            reboot_flush()

        cw.program_target(scope, prog, fw_path)
        scope.arm()
        data = bytearray([0]*5)
        target.simpleserial_write('p', data)
        #target.send_cmd("p", "P", bytearray([0]*5))
        ret = scope.capture()

        # Gather list elements; number of cycles + parameters. ADC counts 4 times each cycle, so we need to divide its count by 4.
        listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
        
        if ret:
            listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
            failList.append(listElement)
            gc.add("reset")
            
            #Device is slow to boot?
            reboot_flush()
        else:
            val = target.simpleserial_read_witherrors('r', 1, glitch_timeout=10, timeout=50) #For loop check
            if val['valid'] is False:
                listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                failList.append(listElement)
                gc.add("reset")
            else:

                if val['payload'] == bytearray([1]): #for loop check
                    listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                    hitList.append(listElement)
                    print(end_time-start_time)
                    gc.add("success")
                else:
                    listElement = (end_time - start_time, counter, scope.adc.trig_count/4, scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                    normalList.append(listElement)
                    gc.add("normal")        
        end_time = time.clock_gettime(clock_ID) # Update timer
        counter = counter + 1                   # Update interation counter
# Out:
# ---------------------------------------------------------------------------
# USBErrorNoDevice                          Traceback (most recent call last)
# Cell In[26], line 52
#      48 #gc.set_range("ext_offset", 40, 200)
#      49 #gc.set_range("ext_offset", 1, PROGRAM_MAX_CYCLE_COUNT)
#      50 gc.set_step("ext_offset", 1) # We are interested in the whole cycle search space; set step to 1.
# ---> 52 scope.glitch.repeat = 1 # This says how many pulses the glitch signal has, not how many times we try. Check docs before touching it!
#      53 reboot_flush()
#      54 scope.adc.timeout = 1.5 # Number, in seconds, scope will wait before aborting a capture.
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/common/utils/util.py:417, in DisableNewAttr.__setattr__(self, name, value)
#     416 def __setattr__(self, name, value):
# --> 417     if hasattr(self, '_new_attributes_disabled') and self._new_attributes_disabled and not hasattr(self, name):  # would this create a new attribute?
#     418         #raise AttributeError("Attempt to set unknown attribute in %s"%self.__class__, name)
#     419         other_logger.error("Setting unknown attribute {} in {}".format(name, self.__class__))
#     420         if hasattr(self, '_new_attributes_disabled_strict') and self._new_attributes_disabled_strict and not hasattr(self, name):
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:601, in GlitchSettings.repeat(self)
#     567 @property
#     568 def repeat(self) -> Union[int, list]:
#     569     """The number of glitch pulses to generate per trigger.
#     570
#     571     When the glitch module is triggered, it produces a number of pulses
#    (...)
#     599        ValueError: if any value outside [1, 8192]
#     600     """
# --> 601     return self.cwg.getRepeat()
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:1164, in ChipWhispererGlitch.getRepeat(self)
#    1162 def getRepeat(self):
#    1163     """Get number of glitches to occur after a trigger"""
# -> 1164     repeats = self.readRepeat()
#    1165     if type(repeats) is int:
#    1166         return repeats
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:1145, in ChipWhispererGlitch.readRepeat(self)
#    1143 def readRepeat(self):
#    1144     num_glitches = self.getNumGlitches()
# -> 1145     resp = self.oa.sendMessage(CODE_READ, "CLOCKGLITCH_SETTINGS", Validate=False, maxResp=8)
#    1146     num = resp[6]
#    1147     num |= ((resp[7] & ~(self.CLKSOURCE_MASK)) >> 2) << 8
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:290, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     288 address = self._address_str2int(address)
#     289 if mode != CODE_WRITE:
# --> 290     return self.msg_read(address, maxResp)
#     291 self.msg_write(address, payload)
#     292 if Validate:
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:214, in OpenADCInterface.msg_read(self, address, max_resp)
#     211         scope_logger.warning("The error trace below will show you what led to this:")
#     212         raise ValueError
# --> 214     data = self.serial.cmdReadMem(address, max_resp)
#     215 else:
#     216     self._send_msg_hdr(CODE_READ, address, 0)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:889, in NAEUSB.cmdReadMem(self, addr, dlen)
#     883 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     884     """
#     885     Send command to read over external memory interface from FPGA. Automatically
#     886     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     887     """
# --> 889     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:635, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     633 dlen = int(dlen)
#     634 if dlen < NAEUSB_CTRL_IO_THRESHOLD:
# --> 635     data = self._cmd_readmem_ctrl(addr, dlen)
#     636 else:
#     637     data = self._cmd_readmem_bulk(addr, dlen)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:616, in NAEUSB_Backend._cmd_readmem_ctrl(self, addr, dlen)
#     610 def _cmd_readmem_ctrl(self, addr : int, dlen : int):
#     611     """Reads data from the external memory interface over the control-transfer endpoint.
#     612
#     613     Returns:
#     614         The received data.
#     615     """
# --> 616     self._cmd_ctrl_send_header(addr, dlen, self.CMD_READMEM_CTRL);
#     617     return self.readCtrl(self.CMD_READMEM_CTRL, dlen=dlen)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:608, in NAEUSB_Backend._cmd_ctrl_send_header(self, addr, dlen, cmd)
#     606 # TODO: Alloc header class member? Won't hafta alloc mem every read and writectrl call...
#     607 pload = make_len_addr(dlen, addr)
# --> 608 self._cmd_ctrl_send_data(pload, cmd)
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:597, in NAEUSB_Backend._cmd_ctrl_send_data(self, pload, cmd)
#     593 """Sends data over the control-transfer channel and attempts a pipe error fix if an initial
#     594 error occured.
#     595 """
#     596 try:
# --> 597     self.sendCtrl(cmd, data=pload)
#     598 except usb1.USBErrorPipe:
#     599     naeusb_logger.info("Attempting pipe error fix - typically safe to ignore")
#
# File ~/Projects/ChipWhisperer/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:551, in NAEUSB_Backend.sendCtrl(self, cmd, value, data)
#     549 if len(data) > NAEUSB_CTRL_IO_MAX:
#     550     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 551 self.handle.controlWrite(0x41, cmd, value, 0, data, timeout=self._timeout)
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:1406, in USBDeviceHandle.controlWrite(self, request_type, request, value, index, data, timeout)
#    1404 # pylint: enable=undefined-variable
#    1405 data, _ = create_initialised_buffer(data)
# -> 1406 return self._controlTransfer(request_type, request, value, index, data,
#    1407                              sizeof(data), timeout)
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:1383, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
#    1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
# -> 1383     mayRaiseUSBError(result)
#    1384     return result
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:129, in mayRaiseUSBError(value, __raiseUSBError)
#     123 def mayRaiseUSBError(
#     124         value,
#     125         # Avoid globals lookup on call to work during interpreter shutdown.
#     126         __raiseUSBError=raiseUSBError,
#     127     ):
#     128     if value < 0:
# --> 129         __raiseUSBError(value)
#     130     return value
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/usb1/__init__.py:121, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     115 def raiseUSBError(
#     116         value,
#     117         # Avoid globals lookup on call to work during interpreter shutdown.
#     118         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     119         __USBError=USBError,
#     120     ): # pylint: disable=dangerous-default-value
# --> 121     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorNoDevice: LIBUSB_ERROR_NO_DEVICE [-4]

# %%
# Dump results into .txt files
with open('failList.txt', 'w') as file:
    for item in failList:
        file.write(str(item) + "," + '\n')
with open('hitList.txt', 'w') as file:
    for item in hitList:
        file.write(str(item) + "," + '\n')
with open('normalList.txt', 'w') as file:
    for item in normalList:
        file.write(str(item) + "," + '\n')

# %%
hitList
# Out:
# []

# %%
failList

# %%
normalList #494370.0
# Out:
# [(0.0, 1, 1052.0, 3500, 2300, 786),
#  (7.679925999836996, 2, 1044.0, 3500, 2300, 787),
#  (15.346898999996483, 3, 1044.0, 3500, 2300, 788),
#  (23.007294999901205, 4, 1044.0, 3500, 2300, 789),
#  (31.003224999876693, 5, 1044.0, 3500, 2300, 790),
#  (38.90618099994026, 6, 1045.0, 3500, 2300, 791),
#  (46.75622499990277, 7, 1044.0, 3500, 2300, 792),
#  (54.43091299990192, 8, 1044.0, 3500, 2300, 793),
#  (62.12064399989322, 9, 1045.0, 3500, 2300, 794),
#  (69.90556999994442, 10, 1044.0, 3500, 2300, 795),
#  (77.59064599988051, 11, 1044.0, 3500, 2300, 796),
#  (85.25180499977432, 12, 1044.0, 3500, 2300, 797),
#  (92.91733499988914, 13, 1044.0, 3500, 2300, 798),
#  (100.58244299981743, 14, 1044.0, 3500, 2300, 799),
#  (108.25911399978213, 15, 1046.0, 3500, 2300, 800),
#  (115.94570499984547, 16, 1044.0, 3500, 2300, 801),
#  (123.62163999979384, 17, 1046.0, 3500, 2300, 802),
#  (131.3180229999125, 18, 1044.0, 3500, 2300, 803),
#  (1484.8661829999182, 179, 1044.0, 3500, 2300, 804),
#  (1492.6117039998062, 180, 1044.0, 3500, 2300, 805),
#  (1500.4446289998014, 181, 1044.0, 3500, 2300, 806),
#  (1508.1206089998595, 182, 1045.0, 3500, 2300, 807),
#  (1515.792258999776, 183, 1044.0, 3500, 2300, 808),
#  (1523.570071999915, 184, 1045.0, 3500, 2300, 809),
#  (1531.2566179998685, 185, 1044.0, 3500, 2300, 810),
#  (1539.0251219999045, 186, 1041.0, 3500, 2300, 811),
#  (1546.8081119998824, 187, 1030.0, 3500, 2300, 812),
#  (1554.50311099994, 188, 1044.0, 3500, 2300, 813),
#  (1562.2125929999165, 189, 1045.0, 3500, 2300, 814),
#  (1570.0158609999344, 190, 1044.0, 3500, 2300, 815),
#  (1577.8427639999427, 191, 1044.0, 3500, 2300, 816),
#  (1585.6021489999257, 192, 1044.0, 3500, 2300, 817)]

# %%
results = gc.calc(ignore_params=["width", "offset"], sort="success_rate")
results

# %% [markdown]
# And one for your width/offset settings:

# %%
results = gc.calc(sort="total")
results

# %%
scope.dis()
target.dis()

# %%
assert broken is True

# %%
# Target cycle calculated from RTL simulation.
IF_CONDITION = 377502

# Cycles spent bootstrapping and initializing I/O. Chipwhisperer does not count that time. So, subtract that time
MAIN_START = 5295

# Chipwhisperer adds two instructions before the funciton call we are simulating. So, Add that time.
# Also, add time to account for the trigger calls. Exact time is unknown for lowering, assume similar to raising = 45.
CYCLES_FOR_STORE = 6  # Cycles for a storing a word, i.e., 'sw'
CYCLES_FOR_ADD = 2    # Cycles to add an immediate, i.e., 'addi'

# Accruracy for estimations seems to aim a little high for samples on CW, so, adjust it down.
AVERAGE_ERROR = -50.167
OFFSET = int(CYCLES_FOR_STORE + CYCLES_FOR_ADD + AVERAGE_ERROR)


# Note 1: Cycle count found running program and dividing the scope.adc.trig_count, after trigger has been lowered, by 4.
# Note 2: The ADC increments four times each cycle by default. If your numbers are very off, check!
PROGRAM_AVERAGE_CYCLE_COUNT = 494395             # Number of cycles a normal execution takes.
SIMULATION_MAX_CYCLE_COUNT = 377538 - MAIN_START # Number of cycles a simulated execution takes.
SIMULATION_IF_CYCLE_COUNT = IF_CONDITION - MAIN_START + OFFSET
TIME_SCALAR = PROGRAM_AVERAGE_CYCLE_COUNT/SIMULATION_MAX_CYCLE_COUNT # Quotient of the two program runs.
INVERSE_SCALE = SIMULATION_MAX_CYCLE_COUNT/PROGRAM_AVERAGE_CYCLE_COUNT

TARGET_CYCLE = int((SIMULATION_IF_CYCLE_COUNT) * TIME_SCALAR)
ACTUAL = 494254

# Offset start instruction and scale simulated result to match concreate results.
print("Forward  = " + str(TARGET))
print("Backward = " + str(PROGRAM_AVERAGE_CYCLE_COUNT - int(TIME_SCALAR*68) - 55))
print("actual   = 494254")
print("Error    = " + str(ACTUAL - TARGET_CYCLE))
print("%Error   = " + str(abs(1 - ACTUAL/TARGET_CYCLE)*100))
# Out:
# Forward  = 494291
# Backward = 494250
# actual   = 494254
# Error    = -37
# %Error   = 0.007485469086021546
